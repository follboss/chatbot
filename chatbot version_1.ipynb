# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np
import itertools
plt.style.use('fivethirtyeight')

# %%
covidData = pd.read_csv('Cleaned-Data.csv')
rawData = pd.read_csv('Raw-Data.csv')

# %%
newData = pd.read_csv('datasets_575188_1041634_modified_COVID19_open_line_list.csv')

# %%
newData.outcome.unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
newData["symptom"] = None

# %%
newData.loc[newData['outcome'] == 1, ['symptom']] = "Negatif Covid mild"
newData.loc[newData.outcome == 0, ['symptom']] = "Negatif Covid"
newData.loc[newData.outcome == 2, ['symptom']] = "Positif Covid moder"
newData.loc[newData.outcome == 3, ['symptom']] = "Positif Covid sever"

# %%
 training_dataset = newData[['age', 'gender', 'onset_symptoms_to_admission_hospital',
       'admission_hospital_to_confirmation', 'fever', 'caugh', 'chills',
       'nausea', 'dyspnea', 'anorexia', 'pneumonitis', 'rhinorrhea',
       'diarrhea', 'fatigue', 'sore muscle', 'sore throat',
       'respiratory symptoms', 'headache', 'weakness', 'dizziness',
       'pleural effusion', ' chest pain', 'symptom']]

# %%
corr_matrix = training_dataset.corr()

# %%
cor_target = abs(corr_matrix)
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.4]
relevant_features
# Out:
#                                       age  gender  \
# age                                   1.0     NaN
# gender                                NaN     1.0
# onset_symptoms_to_admission_hospital  NaN     NaN
# admission_hospital_to_confirmation    NaN     NaN
# fever                                 NaN     NaN
# caugh                                 NaN     NaN
# chills                                NaN     NaN
# nausea                                NaN     NaN
# dyspnea                               NaN     NaN
# anorexia                              NaN     NaN
# pneumonitis                           NaN     NaN
# rhinorrhea                            NaN     NaN
# diarrhea                              NaN     NaN
# fatigue                               NaN     NaN
# sore muscle                           NaN     NaN
# sore throat                           NaN     NaN
# respiratory symptoms                  NaN     NaN
# headache                              NaN     NaN
# weakness                              NaN     NaN
# dizziness                             NaN     NaN
# pleural effusion                      NaN     NaN
#  chest pain                           NaN     NaN
#
#                                       onset_symptoms_to_admission_hospital  \
# age                                                                    NaN
# gender                                                                 NaN
# onset_symptoms_to_admission_hospital                                   1.0
# admission_hospital_to_confirmation                                     NaN
# fever                                                                  NaN
# caugh                                                                  NaN
# chills                                                                 NaN
# nausea                                                                 NaN
# dyspnea                                                                NaN
# anorexia                                                               NaN
# pneumonitis                                                            NaN
# rhinorrhea                                                             NaN
# diarrhea                                                               NaN
# fatigue                                                                NaN
# sore muscle                                                            NaN
# sore throat                                                            NaN
# respiratory symptoms                                                   NaN
# headache                                                               NaN
# weakness                                                               NaN
# dizziness                                                              NaN
# pleural effusion                                                       NaN
#  chest pain                                                            NaN
#
#                                       admission_hospital_to_confirmation  \
# age                                                                  NaN
# gender                                                               NaN
# onset_symptoms_to_admission_hospital                                 NaN
# admission_hospital_to_confirmation                                   1.0
# fever                                                                NaN
# caugh                                                                NaN
# chills                                                               NaN
# nausea                                                               NaN
# dyspnea                                                              NaN
# anorexia                                                             NaN
# pneumonitis                                                          NaN
# rhinorrhea                                                           NaN
# diarrhea                                                             NaN
# fatigue                                                              NaN
# sore muscle                                                          NaN
# sore throat                                                          NaN
# respiratory symptoms                                                 NaN
# headache                                                             NaN
# weakness                                                             NaN
# dizziness                                                            NaN
# pleural effusion                                                     NaN
#  chest pain                                                          NaN
#
#                                       fever  caugh  chills  nausea  dyspnea  \
# age                                     NaN    NaN     NaN     NaN      NaN
# gender                                  NaN    NaN     NaN     NaN      NaN
# onset_symptoms_to_admission_hospital    NaN    NaN     NaN     NaN      NaN
# admission_hospital_to_confirmation      NaN    NaN     NaN     NaN      NaN
# fever                                   1.0    NaN     NaN     NaN      NaN
# caugh                                   NaN    1.0     NaN     NaN      NaN
# chills                                  NaN    NaN     1.0     NaN      NaN
# nausea                                  NaN    NaN     NaN     1.0      NaN
# dyspnea                                 NaN    NaN     NaN     NaN      1.0
# anorexia                                NaN    NaN     NaN     NaN      NaN
# pneumonitis                             NaN    NaN     NaN     NaN      NaN
# rhinorrhea                              NaN    NaN     NaN     NaN      NaN
# diarrhea                                NaN    NaN     NaN     NaN      NaN
# fatigue                                 NaN    NaN     NaN     NaN      NaN
# sore muscle                             NaN    NaN     NaN     NaN      NaN
# sore throat                             NaN    NaN     NaN     NaN      NaN
# respiratory symptoms                    NaN    NaN     NaN     NaN      NaN
# headache                                NaN    NaN     NaN     NaN      NaN
# weakness                                NaN    NaN     NaN     NaN      NaN
# dizziness                               NaN    NaN     NaN     NaN      NaN
# pleural effusion                        NaN    NaN     NaN     NaN      NaN
#  chest pain                             NaN    NaN     NaN     NaN      NaN
#
#                                       anorexia  ...  diarrhea  fatigue  \
# age                                        NaN  ...       NaN      NaN
# gender                                     NaN  ...       NaN      NaN
# onset_symptoms_to_admission_hospital       NaN  ...       NaN      NaN
# admission_hospital_to_confirmation         NaN  ...       NaN      NaN
# fever                                      NaN  ...       NaN      NaN
# caugh                                      NaN  ...       NaN      NaN
# chills                                     NaN  ...       NaN      NaN
# nausea                                     NaN  ...       NaN      NaN
# dyspnea                                    NaN  ...       NaN      NaN
# anorexia                                   1.0  ...       NaN      NaN
# pneumonitis                                NaN  ...       NaN      NaN
# rhinorrhea                                 NaN  ...       NaN      NaN
# diarrhea                                   NaN  ...       1.0      NaN
# fatigue                                    NaN  ...       NaN      1.0
# sore muscle                                NaN  ...       NaN      NaN
# sore throat                                NaN  ...       NaN      NaN
# respiratory symptoms                       NaN  ...       NaN      NaN
# headache                                   NaN  ...       NaN      NaN
# weakness                                   NaN  ...       NaN      NaN
# dizziness                                  NaN  ...       NaN      NaN
# pleural effusion                           NaN  ...       NaN      NaN
#  chest pain                                NaN  ...       NaN      NaN
#
#                                       sore muscle  sore throat  \
# age                                           NaN          NaN
# gender                                        NaN          NaN
# onset_symptoms_to_admission_hospital          NaN          NaN
# admission_hospital_to_confirmation            NaN          NaN
# fever                                         NaN          NaN
# caugh                                         NaN          NaN
# chills                                        NaN          NaN
# nausea                                        NaN          NaN
# dyspnea                                       NaN          NaN
# anorexia                                      NaN          NaN
# pneumonitis                                   NaN          NaN
# rhinorrhea                                    NaN          NaN
# diarrhea                                      NaN          NaN
# fatigue                                       NaN          NaN
# sore muscle                                   1.0          NaN
# sore throat                                   NaN          1.0
# respiratory symptoms                          NaN          NaN
# headache                                      NaN          NaN
# weakness                                      NaN          NaN
# dizziness                                     NaN          NaN
# pleural effusion                              NaN          NaN
#  chest pain                                   NaN          NaN
#
#                                       respiratory symptoms  headache  \
# age                                                    NaN       NaN
# gender                                                 NaN       NaN
# onset_symptoms_to_admission_hospital                   NaN       NaN
# admission_hospital_to_confirmation                     NaN       NaN
# fever                                                  NaN       NaN
# caugh                                                  NaN       NaN
# chills                                                 NaN       NaN
# nausea                                                 NaN       NaN
# dyspnea                                                NaN       NaN
# anorexia                                               NaN       NaN
# pneumonitis                                            NaN       NaN
# rhinorrhea                                             NaN       NaN
# diarrhea                                               NaN       NaN
# fatigue                                                NaN       NaN
# sore muscle                                            NaN       NaN
# sore throat                                            NaN       NaN
# respiratory symptoms                                   1.0       NaN
# headache                                               NaN       1.0
# weakness                                               NaN       NaN
# dizziness                                              NaN       NaN
# pleural effusion                                       NaN       NaN
#  chest pain                                            NaN       NaN
#
#                                       weakness  dizziness  pleural effusion  \
# age                                        NaN        NaN               NaN
# gender                                     NaN        NaN               NaN
# onset_symptoms_to_admission_hospital       NaN        NaN               NaN
# admission_hospital_to_confirmation         NaN        NaN               NaN
# fever                                      NaN        NaN               NaN
# caugh                                      NaN        NaN               NaN
# chills                                     NaN        NaN               NaN
# nausea                                     NaN        NaN               NaN
# dyspnea                                    NaN        NaN               NaN
# anorexia                                   NaN        NaN               NaN
# pneumonitis                                NaN        NaN               NaN
# rhinorrhea                                 NaN        NaN               NaN
# diarrhea                                   NaN        NaN               NaN
# fatigue                                    NaN        NaN               NaN
# sore muscle                                NaN        NaN               NaN
# sore throat                                NaN        NaN               NaN
# respiratory symptoms                       NaN        NaN               NaN
# headache                                   NaN        NaN               NaN
# weakness                                   1.0        NaN               NaN
# dizziness                                  NaN        1.0               NaN
# pleural effusion                           NaN        NaN               1.0
#  chest pain                                NaN        NaN               NaN
#
#                                        chest pain
# age                                           NaN
# gender                                        NaN
# onset_symptoms_to_admission_hospital          NaN
# admission_hospital_to_confirmation            NaN
# fever                                         NaN
# caugh                                         NaN
# chills                                        NaN
# nausea                                        NaN
# dyspnea                                       NaN
# anorexia                                      NaN
# pneumonitis                                   NaN
# rhinorrhea                                    NaN
# diarrhea                                      NaN
# fatigue                                       NaN
# sore muscle                                   NaN
# sore throat                                   NaN
# respiratory symptoms                          NaN
# headache                                      NaN
# weakness                                      NaN
# dizziness                                     NaN
# pleural effusion                              NaN
#  chest pain                                   1.0
#
# [22 rows x 22 columns]

# %%
training_data = training_dataset.iloc[:,:-1]

# %%
corr = training_data.corr()

# %%
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.8:
            if columns[j]:
                columns[j] = False
selected_columns = training_data.columns[columns]
training_data = training_data[selected_columns]

# %%
data = training_data

# %%
selected_columns = selected_columns[1:].values
import statsmodels.formula.api as sm
def backwardElimination(x, Y, sl, columns):
    numVars = len(x[0])
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(Y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        if maxVar > sl:
            for j in range(0, numVars - i):
                if (regressor_OLS.pvalues[j].astype(float) == maxVar):
                    x = np.delete(x, j, 1)
                    columns = np.delete(columns, j)
                    
    regressor_OLS.summary()
    return x, columns
SL = 0.05
data_modeled, selected_columns = backwardElimination(data.iloc[:,1:].values, data.iloc[:,0].values, SL, selected_columns)

# %%
result = pd.DataFrame()
result['diagnosis'] = data.iloc[:,0]

# %%
data = pd.DataFrame(data = data_modeled, columns = selected_columns)

# %%
data
# Out:
#      gender  onset_symptoms_to_admission_hospital  \
# 0         0                                     0
# 1         0                                     5
# 2         0                                     0
# 3         1                                     0
# 4         1                                     6
# ..      ...                                   ...
# 295       0                                     3
# 296       0                                    10
# 297       1                                     7
# 298       0                                    12
# 299       1                                     4
#
#      admission_hospital_to_confirmation  fever  caugh  pneumonitis  fatigue  \
# 0                                     1      1      0            0        0
# 1                                     2      1      0            0        0
# 2                                     1      0      1            0        0
# 3                                     6      1      0            0        0
# 4                                     1      1      0            0        0
# ..                                  ...    ...    ...          ...      ...
# 295                                   2      1      0            0        0
# 296                                  12      0      0            0        1
# 297                                  12      0      1            0        0
# 298                                   1      1      1            0        0
# 299                                   1      1      0            0        0
#
#       chest pain
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 295            0
# 296            0
# 297            0
# 298            0
# 299            0
#
# [300 rows x 8 columns]

# %%
# Dimensionality Reduction for removing redundancies
dimensionality_reduction = training_dataset.groupby(training_dataset['symptom']).max()

# %%
dimensionality_reduction
# Out:
#                      age  gender  onset_symptoms_to_admission_hospital  \
# symptom
# Negatif Covid         96       1                                    32
# Negatif Covid mild    73       1                                    13
# Positif Covid moder   85       1                                    10
# Positif Covid sever   67       1                                    12
#
#                      admission_hospital_to_confirmation  fever  caugh  chills  \
# symptom
# Negatif Covid                                        17      1      1       1
# Negatif Covid mild                                   11      1      1       1
# Positif Covid moder                                  12      1      1       0
# Positif Covid sever                                   1      1      1       1
#
#                      nausea  dyspnea  anorexia  ...  diarrhea  fatigue  \
# symptom                                         ...
# Negatif Covid             1        1         1  ...         1        1
# Negatif Covid mild        0        1         0  ...         1        1
# Positif Covid moder       0        1         0  ...         0        1
# Positif Covid sever       0        0         0  ...         0        0
#
#                      sore muscle  sore throat  respiratory symptoms  headache  \
# symptom
# Negatif Covid                  1            1                     1         1
# Negatif Covid mild             0            1                     1         1
# Positif Covid moder            0            0                     0         0
# Positif Covid sever            0            0                     0         0
#
#                      weakness  dizziness  pleural effusion   chest pain
# symptom
# Negatif Covid               1          1                 1            1
# Negatif Covid mild          1          0                 0            0
# Positif Covid moder         0          0                 0            0
# Positif Covid sever         0          0                 0            0
#
# [4 rows x 22 columns]

# %%
# Slicing and Dicing the dataset to separate features from predictions
X = training_dataset.iloc[:, 0:21].values
y = training_dataset.iloc[:, -1].values

# %%
# Encoding String values to integer constants
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(y)

# %%
# Splitting the dataset into training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
# Implementing the Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_predict = classifier.predict(X_test)

from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_predict)
# Out:
# 0.9066666666666666

# %%
# Saving the information of columns
cols     = training_dataset.columns
cols     = cols[:-1]

# %%
# Checking the Important features
importances = classifier.feature_importances_
indices = np.argsort(importances)[::-1]
features = cols

# %%
features
# Out:
# Index(['age', 'gender', 'onset_symptoms_to_admission_hospital',
#        'admission_hospital_to_confirmation', 'fever', 'caugh', 'chills',
#        'nausea', 'dyspnea', 'anorexia', 'pneumonitis', 'rhinorrhea',
#        'diarrhea', 'fatigue', 'sore muscle', 'sore throat',
#        'respiratory symptoms', 'headache', 'weakness', 'dizziness',
#        'pleural effusion', ' chest pain'],
#       dtype='object')

# %%
# Implementing the Visual Tree
from sklearn.tree import _tree

# %%
def chatbot():

    print("Reponsez yes/Yes or no/No pour les symptomes") 
    def print_disease(node):
        #print(node)
        node = node[0]
        #print(len(node))
        val  = node.nonzero() 
        #print(val)
        disease = labelencoder.inverse_transform(val[0])
        return disease
    def tree_to_code(tree, feature_names):
        tree_ = tree.tree_
        #print(tree_)
        feature_name = [
            feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
            for i in tree_.feature
        ]
        #print("def tree({}):".format(", ".join(feature_names)))
        symptoms_present = []
        def recurse(node, depth):
            indent = "  " * depth
            if tree_.feature[node] != _tree.TREE_UNDEFINED:
                name = feature_name[node]
                threshold = tree_.threshold[node]
                print(name + " ?")
                ans = input()
                ans = ans.lower()
                if ans == 'yes':
                    val = 1
                else:
                    val = 0
                if  val <= threshold:
                    recurse(tree_.children_left[node], depth + 1)
                else:
                    symptoms_present.append(name)
                    recurse(tree_.children_right[node], depth + 1)
            else:
                present_disease = print_disease(tree_.value[node])
                print( "D'après les symptomes vous avez " +  present_disease )
                red_cols = dimensionality_reduction.columns 
                symptoms_given = red_cols[dimensionality_reduction.loc[present_disease].values[0].nonzero()]
                print("symptoms present  " + str(list(symptoms_present)))
                print("symptoms given "  +  str(list(symptoms_given)) )  
                confidence_level = (1.0*len(symptoms_present))/len(symptoms_given)
                print("indice de confiance " + str(confidence_level))
    
        recurse(0, 1)
    tree_to_code(classifier,cols)

# %%
chatbot()
# Out:
# Reponsez yes/Yes or no/No pour les symptomes
# admission_hospital_to_confirmation ?
# no
# chills ?
# yes
# admission_hospital_to_confirmation ?
# no
# age ?
# 60
# ['You may have Negatif Covid mild']
# symptoms present  ['chills']
# symptoms given ['age', 'gender', 'onset_symptoms_to_admission_hospital', 'admission_hospital_to_confirmation', 'fever', 'caugh', 'chills', 'dyspnea', 'pneumonitis', 'rhinorrhea', 'diarrhea', 'fatigue', 'sore throat', 'respiratory symptoms', 'headache', 'weakness']
# confidence level is 0.0625
